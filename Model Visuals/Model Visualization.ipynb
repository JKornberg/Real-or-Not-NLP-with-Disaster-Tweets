# %%
import matplotlib.pyplot as plt

plt.figure()
plt.bar(['RF','SVC','MNB','LR','DT','BERT PT','Roberta'],[44.499030,0.732750,1.017396,0.723511,0.881168,15.793601,20.038180])
plt.title('Run Times')
plt.ylabel('Time (seconds)')
# Out:
# Text(0, 0.5, 'Time (seconds)')

# %%
plt.figure()
plt.bar(['RF','SVC','MNB','LR','DT','BERT PT','Roberta'],[0.57983,0.66779,0.78577,0.66656,0.65062,0.83573,0.83205])
plt.title('F1 Scores')
plt.ylabel('F1 Score')
# Out:
# Text(0, 0.5, 'F1 Score')
